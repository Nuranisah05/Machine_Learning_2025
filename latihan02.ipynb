# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
path = "/content/gdrive/MyDrive/PRAKTIKUM ML/Praktikum02"

# %%
# Membaca dataset csv menggunakan pandas
import pandas as pd

df2 = pd.read_csv(path + '/data/500_Person_Gender_Height_Weight_Index.csv')
df2.head()

# Membagi dataset menjadi Training (80%) dan Testing (20%)
train_df2, test_df2 = train_test_split(df2, test_size=0.2, random_state=42)

# Mengambil 10% data Training untuk Validation
train_df2, val_df2 = train_test_split(train_df2, test_size=0.1, random_state=42)

# Menampilkan jumlah data & 5 baris teratas di setiap set
print("\nJumlah data Training:", len(train_df2))
display(train_df2.head())

print("\nJumlah data Validation:", len(val_df2))
display(val_df2.head())

print("\nJumlah data Testing:", len(test_df2))
display(test_df2.head())
# Out:
# Jumlah data Training: 360
#      Gender  Height  Weight  Index
# 151    Male     140      52      3
# 357  Female     186     143      5
# 373  Female     163      63      2
# 227    Male     188     123      4
# 404    Male     193     130      4
# Jumlah data Validation: 40
#      Gender  Height  Weight  Index
# 120  Female     168      87      4
# 128    Male     182     151      5
# 271    Male     152     103      5
# 349  Female     157      60      2
# 272  Female     187     121      4
# Jumlah data Testing: 100
#      Gender  Height  Weight  Index
# 361    Male     161     103      4
# 73     Male     180      75      2
# 374    Male     174      95      4
# 155  Female     179     103      4
# 104  Female     192     140      4
